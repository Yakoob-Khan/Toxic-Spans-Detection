# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-04b8acab22a7> in <module>
#       1 from load_dataset import load_dataset
# ----> 2 from tokenize_data import tokenize_data
#
# ~/Desktop/Thesis/system/code/tokenize_data.py in <module>
#       2 import string
#       3
# ----> 4 from transformers import BertTokenizer
#       5 from load_dataset import load_dataset
#       6
#
# ModuleNotFoundError: No module named 'transformers'

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /opt/anaconda3/lib/python3.7/site-packages (3.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (2020.7.14)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (19.2)
# Requirement already satisfied: sacremoses in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (0.0.43)
# Requirement already satisfied: tokenizers==0.8.1.rc2 in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (0.8.1rc2)
# Requirement already satisfied: sentencepiece!=0.1.92 in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (0.1.91)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (4.46.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (1.17.2)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from transformers) (2.22.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from packaging->transformers) (2.4.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from packaging->transformers) (1.12.0)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (0.13.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.7/site-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2.8)

# %%
import time
start = time.time()
texts, spans = load_dataset("../data/tsd_trian.csv")
end = time.time()
print(f"Time: {end-start}s")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ecef8f339d13> in <module>
#       1 import time
#       2 start = time.time()
# ----> 3 texts, spans = load_dataset("../data/tsd_trian.csv")
#       4 end = time.time()
#       5 print(f"Time: {end-start}s")
#
# NameError: name 'load_dataset' is not defined

# %%
text = "Kill some more kids and then complain about guns, LOL the left is a joke"

print(text[0: 4])
print(text[50:72])
# Out:
# Kill
# LOL the left is a joke

# %%
arr = [0, 0, 1]
print(arr[:-1])
# Out:
# [0, 0]

# %%
from ast import literal_eval

file = open('predictions.txt', 'r') 
i = 0
for line in file.readlines():
    if i == 10:
        break
    # print(len(literal_eval(line)))
    info = literal_eval(line)
    print(f"Text: {info[0]}")
    print(f"Gold: {info[1]}")
    print(f"Pred: {info[2]} \n")
# Out:
# Text: ['What has your body odor to do with anything you right wing idiot.']
# Gold: ['right wing idiot']
# Pred: ['What', 'has', 'your', 'body', 'do', 'anything', 'idiot', '']
#
# Text: ['Such venom and hatred.  You probably have a picture of Kathy Griffin in your room.  No cure for stuck on stupid.']
# Gold: ['stuck', 'stupid']
# Pred: ['Such', 'venom', 'hatred.', ' Yo', ' probabl', ' hav', ' ', ' pictur', ' o', ' Kath', ' i', ' room', '  ', 'o cu', 'e f', 'k ', 'n stup', 'd']
#
# Text: ["Blackmailed is the title of his new book.  Although he probably would get blackmailed more for the things he's done past and present, hehe.  Besides why do you think most of the Republicans are still at his side, they can't be that stupid."]
# Gold: ['stupid']
# Pred: ['Black', 'title', 'of', 'new', 'book', ' Althoug', ' probabl', ' ge', ' blac', ' mor', ' fo', "e'", ' don', ' pas', '  Besid', 's w', 'y ', 't ', 'e Republica', 'd', 'a', 't ', 'e th', 'd']
#
# Text: ['Just stop.  The people who did that with Obama were jerks and morons, not representing the "right".  Same with this trashy mess.  I know many liberal types who are disgusted by the ever-annoying Ms. Griffin.  \n\nNot everything breaks out along party lines and every sane person better hope we never get to that point. If we do, we lose our moral compass and any concept of right vs wrong.']
# Gold: ['jerks', 'morons']
# Pred: ['Just', 'stop.', ' Th', ' peopl', ' wh', ' di', ' tha', ' wit', ' jer', ' an', 'mor', ',', 'not', 'representing', '"right"', ' Sam', 'h', ' mess', ' ', 'y liber', 'l typ', '. Griff', '.  ', '\nNot every', 'ine', 'eve', 't to', 'that ', 'in', 'f ', ' our ', 'oral co', 'pas', ' an', 'ce', 't of ', 'w']
#
# Text: ['This will just force Canada to set up alternative trading arrangements. Angry white men often make terrible decisions.']
# Gold: ['force', 'Angry white men often make terrible decisions']
# Pred: ['This', 'force', 'alternative', 'trading', '.', 'Angry', 'white', 'decisions', '']
#
# Text: ['Good!  White Christians are evil.']
# Gold: ['evil']
# Pred: ['Good', ' Whit', ' Christian', ' evi', '.']
#
# Text: ['Do what most police departments are willing to do when someone fails to obey orders: shoot him to death.\n\n#crazyasscrackalivesmatter']
# Gold: ['shoot him to deat', 'crazyasscrackalivesmatter']
# Pred: ['Do', 'what', 'do', 'when', 'at', '.\n', '#', 'ssc', 'ackalivesm', 'er']
#
# Text: ['I think Americans believe their president should be free to speak to whoever he thinks best.\n\nSo PRC can go suck eggs.']
# Gold: ['suck eggs']
# Pred: ['I', 'think', 'whoever', ' PR', '.']
#
# Text: ["It's still B.S. that non - natives have to import Reindeer if they want to raise them. That law is a big crock of sh*t. I would like to raise my own food."]
# Gold: ['sh*t']
# Pred: ["It'", 'B.S.', 'that', 'non', '-', 'have', 'import', 'Re', 'if', 'want', 'to', '.', 'That', 'big', 'of', 'h', ' ', 'ike ', '']
#
# Text: ['Can you test for stupidity?']
# Gold: ['stupidity']
# Pred: ['Can', 'for', 'stupidity', '']
#
# Text: ['And with it goes $1-Billion in taxpayer subsidies.  Canadians are such suckers!']
# Gold: ['suckers']
# Pred: ['And', 'ion', 'in', 'yer', ' suc', '!']
#
# Text: ['Yeah, it gets so dumb it almost reaches the far right.']
# Gold: ['dumb']
# Pred: ['Yeah,', 'it', 'so', 'far', 'right.']
#
# Text: ['Wow! You are one venom-filled zealot.\n\nLet me just ask one very simple question: Have you ever met Ron and had a conversation with him and his wife, Janet?\n\nIf you had any integrity, you would own your comments attacking a very decent, modest individual, by posting under your real name.\n\nBut you are sick with your irrational fanaticism and afraid to come out of your "spider hole." You\'ve made clear from past posts that you haven\'t the foggiest idea of the actual facts regarding the community or the radical zone change. But you have some weird delusion that you know best about what\'s good for society, and yet you are pathetically ignorant and without any evidence of empathy or human compassion.\n\nPlease, get some counseling.\n\n-- Paul']
# Gold: ['ignorant']
# Pred: ['Wow!', 'You', 'one', 'venom-filled', '\nLe', ' simpl', 'n', ' Hav', ' yo', ' eve', ' Ro', ' an', ' ha', ' ', 'e', ' Janet', '\n\n', 'f y', 'd a', 'y integri', ', y', 'd o', 'n yo', 'r commen', 's attacki', ', mode', 't individua', 'r yo', 'r re', 'l na', '.\n\n', 'ck w', 'th y', 'ur irratio', 'to c', 'ut', 'ur "spi', 'er h', '." You', 've m', 'de cl', 'ar f', 'om p', 'ts t', 'at ', 'ou have', 'he ', 'i', 'st i', 'ea', 'al fa', 'ts regard', 'ng ', 'he commun', 'ty', 'he radi', 'al z', 'ne cha', 'e. ', 've s', 'me we', 'rd delus', 'on t', 'ow b', 'st ab', 'ut wh', "'s g", 'od ', 'e', 'y, ', 'nd ', 'et ', 'nt ', 'nd with', 'ut ', 'ny evide', 'ce', 'of empa', 'hy', 'or hu', 'se,', 'g', '\n\n--']
#
# Text: ['Well we know he is a wanker']
# Gold: ['wanker']
# Pred: ['Well', 'wa', 'er']
#
# Text: ["Stupid conspiracy tin-foil hat wearers everywhere unite. As if there aren't enough real, actual  problems to deal with. Evidently false and blatently stupid fake news conspiraccy tales are just further proof that Americans as a populace are way too stupid to be allowed out without adult supervision."]
# Gold: ['Stupid', 'stupid', 'stupid']
# Pred: ['Stupid', 'hat', 'unite', 'As', "'", 'enough', 'real,', 'h', 'Evid', 'blat', 'piracc', ' furthe', ' proo', ' tha', ' a', ' wa', ' b', ' allowe', ' ou', ' adul']
#
# Text: ["There is no bill. The 2% figure is a guideline. Numerous other countries are below Canada in their contributions and Canada spends a great deal of money on defense related activities that don't qualify for NATO, but do contribute to NATO. Coast Guard, for example. \n\nIn other words, you're whining is misplaced. You've admitted you are an American and no doubt a Trump supporter. Good luck with acquiring support in Canada for that hapless buffoon."]
# Gold: ['Good luck with acquiring support in Canada for that hapless buffoon']
# Pred: ['There', 'is', 'no', 'bill.', 'The', '2', 'figure', 'is', 'a', 'guideline', 'Numerous', 'other', 'below', 'in', 'their', 'contributions', 'and', 'a', 'great', 'of', 'on', 'defense', 'related', 'activities', 'that', "don'", 'for', 'NATO,', 'do', 'contribute', 'to', 'NATO.', 'Coast', 'Guard,', '.', '\n\n', 'n oth', 'd', "ou'", ' whini', 's mi', 'e', ". You'", 'e admitt', 'u a', 'e ', 'n Americ', 'n a', 'd ', 't', 'e', 'h acquiri', 'g suppo', 't ', ' bu', 'n']
#
# Text: ['with all the ignorant left wingers here perhaps we can get them some help with thier stupidity']
# Gold: ['ignorant']
# Pred: ['left', 'here', 'thier']
#
# Text: ['Wow, how times have changed! All hail the muslim. It wasn\'t so very long ago that Christians were told to remove all crosses from government properties in Hawaii and even some privately owned churches were heartily challenged. Now we have foreign born muslims on the front page and their "right" to be is heavily protected. Go figure.']
# Gold: []
# Pred: ['Wow', 'have', '!', "'", 'all', 'crosses', 'government', 'in', 'some', 'churches', 'on', 'front', 'and', '"right"', 'to', 'be', 'figure.']
#
# Text: ['so in effect the petty childish nature of the DEMS played out by the most useless president of modern times! , well trump will easily be making any memory of Nobama be history very shortly']
# Gold: ['useless']
# Pred: ['so', 'in', 'child', 'nature', 'of', 'the', 'DEMS', 'played', 'most', 'president', 'of', 'times', ',', 'be', 'any', 'of', 'Noba', 'be', 'shortly']
#
# Text: ['Mr. Keller: \nExcellent Sir, its called keeping your Powder Dry. \n\nPS: Mulcair, is an idiot.']
# Gold: ['idiot']
# Pred: ['Mr.', 'Keller:', '\nExcellen', ' Si', ' it', ' keepin', ' P', 'y', ' \n\n', 'S:', 'Mulca', 'is', 'an id', 'o']
#
# Text: ['Sluts come in both male and female.  \n\nWhen two sluts fornicate without simple, cheap, readily available contraception (supposedly from Planned Parenthood) unwanted children are often the result.\n\nDilatation and curettage.\n\nStir.  Repeat.  \n\nStir. Repeat.']
# Gold: ['Sluts', 'sluts']
# Pred: ['Sluts', 'come', 'in', 'male', 'female.', ' \n\nW', 'en ', 'wo sl', 'ts fornic', 'ut simp', 'e, che', 'p, read', 'ly availa', 'le contracept', 'o', 'ly f', 'om Plan', 'ed Parenth', 'd) unwan', 'ed child', 'en ', 'he resu', 't.\n\nDilata', 'and curett', ' \n\nStir']
#
# Text: ['"This news source has been on Trump\'s side most of the way?"  HA! HA! HA! HA! Where do these Bozos come from?  Sooo many idiots, sooo little time.']
# Gold: ["Trump's"]
# Pred: ['"This', 'source', 'side', '?', ' H', 'H', 'H', 'H', ' Wher', ' B', ' com', 'e tim']
#
# Text: ["Iff'n y'all are a conservative and read the bahble the y'all can rape the little girls."]
# Gold: ['bahble', 'can rape the little girls']
# Pred: ['If', "'n", 'all', 'conservative', 'read', 'all', 'rape', 'little', 'girls', '']
#
# Text: ['your a nut job liberal troll of bs,, save it loser,, we laugh at the complete nonsense, blaming harris bs,, god you liberals never change, always consistently ignorant, lying and full of it..']
# Gold: ['nut', 'ignorant']
# Pred: ['your', 'liberal', 'troll', 'of', 'b', ',,', 'complete', ',', 'laming', 'rri', 'b', ',,', 'god', ',', ' ', 'f ', '.']
#
# Text: ['Idiots, you HAVE a job!!! Resign and go sell apples at the station.']
# Gold: []
# Pred: ['Idio', ' ', 'ou ', ' ', 'ob!!!', 'esign ', 'nd ', 'o ', 'pples ', 'tation.']
#
# Text: ['Go to hell. you and George Soros and the Antifa!']
# Gold: []
# Pred: ['Go', ' ', 'ou ', 'nd ', 'eorge ', 'os ', 'he ', 'ntifa!']
#
# Text: ['I\'d make this fantastic woman president tomorrow. Or Lindiwe Sisulu for that matter.\n\nAnd when she says "They said they are going ahead with charging me, irrespective of the fact that they are illegitimate" all I would add is that yes, that\'s true they are a total bunch of useless b*stards.....']
# Gold: ['illegitimate', 'useless b*stards']
# Pred: ["I'", 'this', 'fantastic', 'woman', 'president', 'Or', 'Lin', 'Si', 'for', '.', '\nAn', ' whe', ' ', ' ar', ' wit', ' chargin', ' me', 'irr', ' ar', ' illegitimat', 'add', 'that', 'yes,', "that'", 'true', 'total', 'of', 'useless', 'b*', '']
#
# Text: ["So next year if you apply for yours, then you're a hypocrite, Mike."]
# Gold: ['hypocrite']
# Pred: ['So', 'apply', 'for', 'yours,', "'re", 'a', 'ypocrite', ' ', 'ike.']
#
# Text: ["Trump is definitely a worthless stain on America.\nHe's definitely a sick, fascist, white supremacist traitor."]
# Gold: ['fascist', 'supremacist traitor']
# Pred: ['Trump', 'definitely', 'on', '.', "'", 'definitely', ',', ' ', 'hite ', 'rema', 'st ', 'raitor.', '']
#
# Text: ['idk the devil makes some damn fine salad....']
# Gold: ['devil']
# Pred: ['id', 'fine', '.']
#
# Text: ['He should have died in Afghanistan and be with Satan now--but we are stuck with this deviant killer.']
# Gold: ['He should have', 'killer']
# Pred: ['He', 'have', 'be', 'but', 'viant', 'killer', '']
#
# Text: ["No shit,  Sherlock.   The military is always locked and loaded.   Had you been a man and served when called upon instead of being a draft dodging coward,  you'd know this. \n\nSomeone put a muzzle on this idiot."]
# Gold: ['shit', 'idiot']
# Pred: ['No', ' ', 'Sherlock.', 'e milita', 's lock', 'e', '.  ', 'you ', 'e', 'n a', 'man', 'and se', 'hen ca', 'led ', ' of b', 'i', 'g a d', 'af', 'ing cow', ' ', ' ']
#
# Text: ["My all time favorites are still Wyoming College (spend $20K per year on something slightly more legit than an online diploma mill and live in a trailer in rural Wyoming) and the now defunct Ave Maria College (come and hear Fr. Gruner's conspiracy theories and other schimatic garbage.)"]
# Gold: ['garbage']
# Pred: ['My', 'favorites', 'Wyoming', 'College', 'spend', 'on', 'something', 'more', 'an', 'online', 'diploma', 'mill', 'live', 'trailer', 'rural', 'Ave', 'Maria', 'College', '(come', 'Fr', 'theories', 'chi', ')']
#
# Text: ['Had to toss in your racist viewpoint by saying "white people," thou hypocrite.']
# Gold: ['white people', 'hypocrite']
# Pred: ['Had', 'toss', 'in', 'your', 'racist', 'viewpoint', 'saying', '"', 'hite ', 'eople,', ' ', 'ocrite.', '']
#
# Text: ['Only an idiot would use and believe anything this This Republican propaganda machine publishes: www.realclearpolitics.com']
# Gold: ['idiot']
# Pred: ['Only', 'use', 'This', 'Republican', 'publishes:', '.', 'ar', '.com']
#
# Text: ['Anti-vaccine fools reap what you sow.']
# Gold: ['fools']
# Pred: ['Anti-vaccine', 'fool', '.']
#
# Text: ["Yes Randy you are right!!! Why does this make front page news??? I lived in McGrath during the 80's and -50 was a common thing.  Thank goodness the weather has changed or these pansy ass journalists would freeze to death!!!"]
# Gold: []
# Pred: ['Yes', 'Randy', 'you', 'are', 'right', '!', 'Why', 'make', 'page', '???', 'I', 'lived', 'in', 'McGrath', "'", '-50', '.', ' Than', ' goodnes', ' journalist', 'h!!']
#
# Text: ['Trump makes it clear: Trumpcare is all about the tax cuts to the rich.\n\n\nThat part he\'s crystal clear on, he\'s not confused or crazy-sounding. \n\n\n\n\n     He\'s got this part down pat—taking health care away from millions is going to be a huge boon to the wealthy, \n\n\n\n\n      "tremendous savings" in taxes.\n\n\n\n\n      That\'s all this has ever been about—now we\'ve got it straight from the ass\'s mouth.']
# Gold: ["ass's mouth"]
# Pred: ['Trump', 'it', 'clear:', 'care', 'about', 'cuts', 'to', '\n\nTh', 'h', 's cryst', 'l cle', 'r o', 'he', 't confus', 'd ', 'z', '\n', '\n\n ', 'art dow', ' pat—t', 'king', 'heal', 'e away f', 'om', 'is', 'g', 'ing ', ' be', 'a ', ' ', 'e wealthy,', '\n\n\n\n\n  ', '  ', 'ous s', 'ing', "   That's", 'l t', ' abo', 'e', 'e got', 'i']
#
# Text: ["I don't believe you can justify your two statements. The first is plainly untrue, even idiotic. The second is also untrue to the point of idiocy."]
# Gold: ['idiotic']
# Pred: ['I', "don't", 'you', 'justify', 'your', 'two', 'statements.', 'plain', 'tr', ',', 'even', 'idiotic', ' ', 'lso ', 'ntrue ', 'oint ', 'f ', 'dioc', '']
#
# Text: ["You are the 'perfect' Democratic IDIOT."]
# Gold: ['IDIOT']
# Pred: ['You', 'are', 'the', "'perfect'", 'Democratic', 'IDIOT', '']
#
# Text: ['Stupid argument, although I hesitate to even call it an argument.  Try addressing the issue, instead of making idiotic remarks.']
# Gold: ['Stupid', 'idiotic']
# Pred: ['Stupid', 'argument,', 'although', 'I', 'hesitate', 'call', 'it', 'argument.', ' Tr', ' issue', ' idioti', ' remarks']
#
# Text: ['People are morons, this is the media attempting, along with whom I said above, to discredit Trump, this is VERY predictable.']
# Gold: ['morons', 'attempting']
# Pred: ['People', 'moro', ' ', 'edia ', 'ttempting,', 'a', 'th w', 'om I', 'id a', 'ove, t', ' d', 'dit', 't', 'is i', 'R', '']
#
# Text: ["Oh trust me, the first pockets he will be picking are yours lol! Your a fool if you don't get that. I'm pro not letting any of those bastards in this country but your barking up the wrong tree. Vote libertarian"]
# Gold: ['fool', 'bastards']
# Pred: ['Oh', ',', 'pockets', 'be', 'picking', 'are', 'lol', 'Your', 'a', 'fool', 'if', "don't", 'get', '.', "'m", 'pro', 'in', 'country', 'but', 'your', 'wrong', '.', 'iber']
#
# Text: ['You are well aware that 90% of Catalans voted for Independence.\n\nIf you didn’t vote, it’s your own fault and no one cares what you think because you are a coward.\n\nSuspect if 99.9% had voted for Independence, you would still be asking, “What about the 0.1%?”\n\nCongrats to the Free and Independent Republic of Catalonia']
# Gold: ['coward']
# Pred: ['You', 'are', 'well', 'aware', 'that', '90', 'of', 'Catalans', 'for', 'Independence.', '\nI', ' didn’', 'e', ' it’', ' you', ' ow', ' faul', ' an', ' n', ' on', ' wha', ' ar', ' ', ' cowar', '.', '\nSuspec', ' i', ' 99', ' ha', ' fo', ' Independenc', ' yo', ' b', ' asking', ' “Wha', ' abou', ' ', '.1%?', 'ong', 'o t', 'e Fr', 'd Independe', 't Republ', 'c ', 'f Catalon']
#
# Text: ['I am a firm believer that stupid individuals cause much more harm than malicious individuals.\n\nThis has very strong support in academic research. See the following paper:\n\n_The Basic Laws of Human Stupidity_ at\n\nhttps://trusttheneighbors.files.wordpress.com/2016/05/blhs.pdf\n\n-- Paul']
# Gold: ['stupid']
# Pred: ['I', 'am', 'a', 'firm', 'believer', 'individuals', 'cause', 'much', 'more', 'than', 'malicious', 'individuals', '\nThi', ' ha', ' ver', ' stron', ' suppor', ' i', ' academi', ' researc', ' Se', ' followin', 'r', '\n\n_T', 'e Bas', 's ', 'f Hum', 'idit', '_ ', 't\n\nhttps', 'ust', 'o', 'l', 'ordpre', 'c', '/', 'f', '\n-- ']
#
# Text: ["Less than six months into his presidency, it's clear that Trump is unfit for office.\n\n“There is a sucker born every minute\nEach time the second hand sweeps to the top\nLike dandelions up they pop,\nTheir ears so big, their eyes so wide.\nAnd though I feed ‘em bona fide baloney\nWith no truth in it\nWhy you can bet I’ll find some rube to buy my corn.\n‘Cause there’s a sure-as-shooting sucker born a minute,\nAnd I’m referrin’ to the minute you were born.”"]
# Gold: ['sucker', 'shooting sucker']
# Pred: ['six', 'into', ',', "it'", 'clear', 'that', 'unfit', 'for', 'office.', '\n“Ther', 'ke', '\nEac', ' secon', ' to', '\nLik', ' u', ' po', ' ear', ' big', ' eye', ' s', 'e', '\nAn', ' ', 'bon', 'bal', '\nWit', ' n', ' trut', '\nWh', 'I', ' ru', 'n', '\n‘Caus', ' there', '-as', 'sucker', 'And', '’m', 'referrin’', 'minute', 'you', 'were', 'born.”']
#
# Text: ['A childish display between a bufoon and a moron in a playground fight.']
# Gold: ['moron']
# Pred: ['A', 'child', 'display', 'between', 'ufoon', 'oro', 'playground', 'fight']
#
# Text: ['Stop with the silly suggestions.  We all know what it is.\n\nClowns... Killer clowns...']
# Gold: ['silly', 'Clowns', 'Killer clowns']
# Pred: ['Stop', 'suggestions.', ' al', 's', '\n\nClo', 's', ' clow', '.']
#
# Text: ["Are these some of those Russian pieces of crap that they seem to be building all over Alaska. People don't buy that poorly built Russian houses. You will regret it down the road. Good luck getting them to fix there slapped together houses to."]
# Gold: ['pieces of crap', 'poorly']
# Pred: ['Are', 'that', 'all', '.', "'", 'houses.', 'You', 'road.', 'Good', 'getting', 'fix', 'there', 'houses', 'to.']
#
# Text: ["Not to mention, it ain't any of the freaking busimywho does and doesn't go to communion."]
# Gold: ['freaking']
# Pred: ['Not', ',', 'it', "'t", 'any', 'of', 'the', 'freaking', 'busim', 'ho', 'does', 'and', "'", 'communion.']
#
# Text: ['The Trump barrage of lies continues to defend one lie after another.  Nothing this traitor tweets or says has any truth; never has.  Time for a Revolution.']
# Gold: ['traitor']
# Pred: ['The', 'of', '.', ' Nothin', ' thi', ' traito', ' o', ' ha', ' an', ' ha', 'a Revolutio']
#
# Text: ['So what if Donald is a liar; he has other good qualities, like being a pu**y grabbin racist.  Lol.  Obstruction, collusion & stupidity.  The clown is going down!']
# Gold: ['racist', 'clown']
# Pred: ['So', 'what', 'if', 'Donald', ';', 'has', 'other', 'good', ',', 'like', 'being', 'grab', 'racist', ' ', 'Lo', ' ', 'struction', ' collusio', ' ', ' stupidity', '  T', 'e clo', 'w']
#
# Text: ["Roll a vehicle in a neighborhood = drunk, stupid or both. He's one lucky guy. Kudos to the citizens who helped out."]
# Gold: ['stupid']
# Pred: ['Roll', 'a', 'vehicle', 'in', 'a', 'neighborhood', '=', 'drunk,', 'stupid', 'or', 'both.', "He'", 'one', 'lucky', 'guy.', 'Kudos', 'citizens', 'out.']
#
# Text: ['And I assume the "middle class" includes the high income earning support industries for the oil companies? The racketeer-health care complex in Alaska? The out of state carpetbagging oil industry workers and CEO\'s and shareholders around the world profiting from our natural resources? \n\nGet the idea out of your head that people are paid what they\'re worth.\n\nThe Koch brothers, who inherited their wealth, make 1000 times per hour more than what a nurse\'s aide does. Lazy ass nurse\'s aide!\n\nBecause you live in the Bush, there may be no jobs. Lazy asses. \n\nTough that your culture has been co-opted. All because you wanted to have a nice school in your community so your kids could be part of the dominant culture. Should have raised them stone-age style instead!\n\nI\'m sure all the "middle-class" self-righteous types here invented Western culture and material wealth independently and by the aid of only their ingenious bootstraps. Why should they share with those lazy villagers?']
# Gold: ['Lazy ass', 'Lazy asses', 'lazy']
# Pred: ['And', 'I', 'assume', '"middle', 'class', 'includes', 'the', 'high', 'income', 'earning', 'support', 'industries', 'for', 'oil', 'companies?', 'The', 'racketeer-health', 'care', 'complex', 'in', 'The', 'of', 'carpetbagging', 'oil', 'industry', 'workers', 'and', "CEO'", 'and', 'shareholders', 'around', 'world', 'profiting', 'natural', 'resources', '\n\nG', 'e id', 'a o', 't ', 'r he', 'd wh', 'e', 't', '.\n\n', 'ch brothe', 'ke 1', 'ur m', 'o', 's. L', 'ss nur', "'s ai", 'e!\n\nBec', 'you ', 'B', 'sh, t', ' b', 'j', 'bs. ', 'azy a', 's', 's.', 'ough', 'that', 'your cu', 'be', 'o', 'ted', 'aus', 'd to', 'h', 've a', 'nice s', 'ho', 'l in', 'your comm', 'y so', 'ou', 'd be', 'pa', ' the dom', 'nant cu', 'ure. S', 'ould', '-age ', 's', 'ea', "\n\nI'", 'l the "middle-', 'lass', 'teous', ' here in', 'ented W', 'stern c', 'e and ma', 'erial ', 'e ', 'id o', 's', 'rap', 'thos', 'l']
#
# Text: ['what is too pathetic is the lie you just fell for, no one will loose health care loser, there is to be a national fund to ensure that,,, \nYou are the far nut job lunatic left fringe of stupidity']
# Gold: ['stupidity']
# Pred: ['what', 'lie', 'you', 'just', 'fell', 'for,', 'no', 'one', 'loose', 'health', 'care', 'loser,', 'there', 'to', 'national', 'that', ',,', '\nYo', ' fa', ' lef', ' fring', ' o', ' stupidit']
#
# Text: ["Never uttered or wrote that crap. You're a liar stuck in a pig fight with yourself. Don't forget the lipstick."]
# Gold: []
# Pred: ['Never', 'uttered', 'or', '.', "You're", 'a', 'liar', 'stuck', 'in', 'a', 'pig', 'fight', 'with', '.', "Don'", 'the', 'lipstick.']
#
# Text: ['They need to vote you out!!!! Your a disgrace.']
# Gold: ['Your a disgrace']
# Pred: ['They', 'need', 'you', 'out', '!!!', 'Your', 'a', 'disgrace', '']
#
# Text: ['Fuck off mandydewaal.']
# Gold: ['Fuck off', 'mandydewaal']
# Pred: ['Fuck', 'man', 'de', 'al']
#
# Text: ["NO.  Give us back OUR money and STOP TAKING our money for a USELESS program that has does not work.\nPaying  $1.50 a month for some B$ program that has NOT WORKED is Insane.  You Donkeys are IDIOTS.  \n\nStop taxing us to death.  Remove this Green Fee and work on getting rooftop solar on homes.  HECO is full of cr@p and they have much more solar that can be added.  How can they put up solar farms but can't have home owners get solar on their roofs ?  \n\nThe leadership in this state is nonexistence and the people are SICK of all the fess and taxes.  When are people going to wake up and realize these elected and appointed officials are IDIOTS ?"]
# Gold: ['IDIOTS']
# Pred: ['NO', ' Giv', ' bac', ' ', ' mone', ' an', 'T', ' mone', ' fo', ' ', 'SELES', ' progra', ' tha', ' ha', ' doe', ' no', ' work', '\nPayin', ' ', 'h f', 'r so', 'e ', '$ progr', 'm th', 't h', 's ', 'T WOR', 'D ', 's Insan', '.  ', 'ou ', 're I', 'O', 'S.  ', '\nSto', 'ax', 'us to ', 'ea', '. ', 'e thi', 'en ', 'ee a', 'd ', ' s', 'n', 'ome', 'is', 'ull', 'of ', 'ey h', 've m', 'e so', ' can ', ' ad', 'th', 'y put', 'ar ', 's', 'ut c', "n't ", 'et', ' ro', 'fs ?  \n\nTh', ' l', 'hip i', 'is sta', 's ', 'one', 'nce an', ' pe', 'le', 'are', 'of ', 'ealize ', ' elected ', 'ffic', 's']
#
# Text: ['It will likely be 53K for Justin and Kathleen, actually.  But no matter.   Beats the crap out of the 2500 they will get from CPP........\n\nThe other thing is that the balance in investments can still grow even as you draw down.\n\nAnd yes, there is a minimum withdrawl each year.  But I think it kicks in at about 71.']
# Gold: ['crap']
# Pred: ['It', 'K', 'for', 'Justin', 'Kathleen,', 'actually.', ' Bu', ' n', ' matter', 'ut', 'of ', 'he 2', 'll ', 'om ', '.', 'The o', 'her t', ' is ', 'nc', 'd', 'wn.', 'd', 'is a mi', 'h', ' ', 'ear', ' ', 'ki', 'o']
#
# Text: ["Thanks a lot douchebag. You're the reason the Portland buttfuckers are getting pushed out and moving down south to the Wilsonville area and beyond. Because of you all the stupid fucking assholes that made Portland a place full of stupid fucking assholes are going to try to turn Salem into some kind of new-stupid-fucking-asshole-topia. This will drive up the price of housing and displace  people down here. Having lived in San Clemente for a time myself I think you're dumb as shit to have moved up here. The fucks wrong with you outsider. I hope bums shit in your yard everyday and never let you walk by without demanding spare  change."]
# Gold: ["o try to turn Salem into some kind of new-stupid-fucking-asshole-topia. This will drive up the price of housing and displace  people down here. Having lived in San Clemente for a time myself I think you're dumb as shit to have moved up here. The fuck"]
# Pred: ['Thanks', 'douchebag.', "You're", 'reason', 'Portland', 'are', 'getting', 'out', 'and', 'moving', 'down', 'south', 'to', 'the', 'Wilsonville', 'area', 'and', 'beyond.', 'of', 'fucking', 'that', 'made', 'Portland', 'a', 'place', 'full', 'of', 't', ' ', 'ry ', 'urn ', 'alem ', 'nto ', 'ome ', 'f ', 'ew-s', 'f', 'asshole-topia. ', 'his ', 'rive ', 'f ', 'ousing ', 'is', 'ace ', 'down', 'here.', 'Having', 'lived', 'in', 'San', 'e', 'I', 'think', "you're", 'dumb', 'as', 'have', 'moved', 'up', 'here.', 'The', 'fuck', ' ', 'rong ', 'ith ', 'utsider. ', 'ope ', 'ou ', 'pare ', 'change.']
#
# Text: ['Great commentary. How did the Party of Lincoln deteriorate into the fraudster Party of Trump? How can a man who pretty much shamelessly lies every time he opens his mouth claim Hillary is untruthful (yes she occasionally lies too). How can a man born rich who markets himself as a rich elitist and a reputation sticking it to contractors and investors, claim to represent the middle class? How can a schoolyard bully claim to be a great negotiator?  Trump supporters, have you gone completely nuts?']
# Gold: ['fraudster', 'completely nuts']
# Pred: ['Great', 'commentary', 'How', 'Party', 'of', 'ter', 'into', 'Party', 'of', 'How', 'man', 'who', 'shame', 'opens', 'mouth', 'Hillary', 'untruthful', '(', '.', 'How', 'born', 'who', 'as', 'rich', 't', 'and', 'reputation', 'it', 'contractors', 'claim', 'middle', 'class', 'How', 'claim', 'a', 'great', ' supporter', ' hav', ' nut', '?']
#
# Text: ['Good morning, ducati, Moto guzzi, triumph and Norton. No hogs, not cheap and not female. Have a good day shark.']
# Gold: ['cheap and not female']
# Pred: ['Good', 'morning', 'ducati,', 'Moto', ',', 'triumph', 'Norton.', 'No', 'ho', ',', 'cheap', 'and', 'female', ' ', 'ave ', 'hark.']
#
# Text: ['You win, The stupidest comment of the year .']
# Gold: ['stupidest']
# Pred: ['You', ',', 'est', 'comment', '.']
#
# Text: ['Just ignore the fool.']
# Gold: ['fool']
# Pred: ['Just', 'fool', '']
#
# Text: ['Beijing millionaires and wanna be Beijing millionairesses who squeeze money from the rest of us! And stupid blind white men with blinders!']
# Gold: ['stupid blind', 'white']
# Pred: ['Beijing', 'Beijing', 'airesses', 'squeeze', 'money', 'from', 'of', '!', 'And', 'white', 'with', 'blinders!']
#
# Text: ["You don't inherit, hypocrisy, Farce.  Back to high school for you."]
# Gold: ['hypocrisy']
# Pred: ['You', "don't", 'inherit,', 'ypocrisy', 'arc', 'Back', 'to', 'high', 'school', '.']
#
# Text: ["Because that's your name, which I know since you told me long ago. Take your crazy pill, Don."]
# Gold: ['crazy']
# Pred: ['Because', "that'", 'your', ',', 'which', 'know', 'since', 'you', 'told', 'me', 'ago.', 'Take', 'crazy', 'pill,', 'Don.']
#
# Text: ['Oh no, Kabooby, it\'s not the Dems that are "making us all look like fools", it\'s the Trumpnuts who voted for this clown to head our country.']
# Gold: ['fools']
# Pred: ['Oh', 'no', 'Ka', ',', "'", 'De', 'that', 'are', 'all', 'look', 'like', 'fool', 'or ', 'o ', 'ead ', 'ountry.']
#
# Text: ['Dems are idiots.']
# Gold: ['idiots']
# Pred: ['De', 'idiot', '']
#
# Text: ['The only thing Trump is going to win is a place in the Guinnes Book of Records as the biggest lying and most inept POTUS in US history. Regarding your other comments, the MSM and the DNC don\'t have to "manufacture" anything as long your beloved Twitter-in Chief continues making a fool of himself whenever he speaks or tweets.']
# Gold: ['POTUS']
# Pred: ['The', 'place', 'in', 'the', 'Guinnes', 'of', 'as', 'biggest', 'lying', 'most', 'POTUS', 'in', 'Regarding', 'your', 'other', 'comments,', 'MSM', 'D', "'t", 'have', '"', 'as', 'Twitter-in', 'making', 'of']
#
# Text: ['People insist on being dumb. No other explanation.']
# Gold: ['dumb']
# Pred: ['People', ' ', 'o ', 'ther ', '']
#
# Text: ['You\'re actually so sad it\'s laughable and define the term "usefull idiot".']
# Gold: ['usefull idiot']
# Pred: ["You're", 'so', 'sad', "'", 'able', 'define', 'term', '"', 'sefull ', 'diot"', '']
#
# Text: ["The science makes Manitoba's action stupid!"]
# Gold: ['cience m', 'stupid']
# Pred: ['s', 'ience ', ' ', 'tion s']
#
# Text: ['The grainy photos they release to the public are not the ones They use to find these idiots. Those photos that you see are not for your assistance. They have clear pictures and use that to confuse not only you but the morons who are in the "grainy" picture.']
# Gold: ['idiots', 'morons']
# Pred: ['The', 'grain', 'to', 'public', 'not', 'the', 'ones', 'They', 'use', 'find', 'idiots', ' ', 'hose ', 'hat ', 'or ', 'our ', ' ', 'lear ', 'se ', 'hat ', 'o ', 'onfuse ', 'ot ', 'ou ', 'ut ', 'ron', 'ho ', 'n ', 'grainy', 'icture.']
#
# Text: ['Block this troll. Had enough of this poser']
# Gold: ['troll']
# Pred: ['Block', ' ', 'f ', 'oser']
#
# Text: ["I don't respond to dumb rhetorical questions."]
# Gold: ['dumb']
# Pred: ['I', "don't", 'al', '.']
#
# Text: ['why would you want to legislate stupidity?']
# Gold: ['stupidity']
# Pred: ['why', 'want', 'stupidity', '']
#
# Text: ['Stupid.']
# Gold: []
# Pred: ['Stupid', '']
#
# Text: ['So if I were to say that Islam is being used to create terrorists, which it is, would that be hatred towards Muslims? \nThe gray area on this stupidity is wide and deep.']
# Gold: ['stupidity']
# Pred: ['So', 'if', 'say', 'that', 'being', 'used', 'create', 'terrorists,', 'it', ',', 'hatred', 'towards', '\nTh', ' gra', ' are', ' o', 'dit', ' wid', ' deep']
#
# Text: ['Is there a reason you post nonsense?  Or are you truly so out of it that you believe what you are posting.']
# Gold: ['post nonsense']
# Pred: ['Is', 'reason', ' ', 'Or', 'are', 'so', 'of', 'it', 'that', 'posting.']
#
# Text: ['look, if there is a witness to any action, would not the investigators first talk to the witness?  why, no mention of the witness?  believe you are being stupid.']
# Gold: ['stupid']
# Pred: ['look,', 'if', 'there', 'a', 'any', 'action,', 'would', '?', ' wh', ' n', ' o', ' th', ' witness', '  belie', 'e bei', 'd']
#
# Text: ['What scam are they running now? Watch idiots jump on wagon and toot Walkers horn. I guess PFD is the guarantee for this lie.']
# Gold: ['idiots']
# Pred: ['What', 'are', 'running', 'on', 'wagon', 'Walker', 'horn.', 'guess', 'PF', 'guarantee', 'for', '.']
#
# Text: ["US American = laugh, laugh,laugh. Marvel at the sheer ignorance.\n\nIt was called 'tarsands' in the original process patents. The term 'oil sands' is nothing more than lipstick on a pig."]
# Gold: ['US American', 'ignorance', 'pig']
# Pred: ['US', '=', 'laugh', '.', 'Marvel', 'the', 'sheer', 'ignorance', '\n', 'It', 'was', "'tarsa", "'", 'in', 'the', 'original', 'process', 'patents.', 'The', "'oil", "sands'", 'nothing', 'more', 'lipstick', 'on', 'pig', '']
#
# Text: ["You wouldn't know truth if it came up and smack you on the  butt."]
# Gold: ['butt']
# Pred: ['You', "'t", 'up', 'you', 'on', ' but', '.']
#
# Text: ['An idiot from new york']
# Gold: ['idiot']
# Pred: ['An', 'idiot', 'from', 'new']
#
# Text: ["The economy is stagnant and collapsing.  Who believes we are in a good economic condition? Only the brainwashed who believe the news.  We are about to enter the biggest collapse in human history with the impending death of the US dollar.  Why are people SO CLUELESS? Seriously! We're days away from a massive collapse, people think the economy is ok? WTF?"]
# Gold: []
# Pred: ['The', 'economy', 'tag', 'and', 'collapsing', ' Wh', ' i', ' ', ' goo', ' economi', ' condition', ' Onl', ' brai', 'he', ' wh', ' believ', 'o ent', 'e bigge', 'e ', 'n hum', '.  ', 'LU', ' We', ' a mass', 'p', 'he econ', 'is', '? ']
#
# Text: ["it's a made-up word to hide Islam's paranoid hatred of non-believers, it really is Kuffirphobia, fear of infidels that is driven into the very heart of muslims. We must not allow any religious nutjobs Islam or otherwise to impose their crazy nonsense on others via pain of the law."]
# Gold: ['Kuffirphobia', 'religious nutjobs Islam', 'crazy nonsense']
# Pred: ["it'", '-up', 'word', 'to', "'", 'of', 'non-believers,', 'Ku', 'obia', ' ', 'f ', 'nfid', 'hat ', 'riven ', 'nto ', 'eart ', 'eligious ', 'ob', 'slam ', 'therwise ', 'razy ', 'n ', 'ia ', 'f ', '']
#
# Text: ["Fools and their money are easily parted; but fools with other people's money are even easier to be parted!"]
# Gold: ['Fool', 'but']
# Pred: ['Fool', 'oney ', 'asily ', 'arted; ', 'ut ', 'ools', 'ith ', 'ther ', "eople's", 'ven ', 'asier ', 'arted!']
#
# Text: ['She is weak and useless, time to run her off']
# Gold: ['weak', 'useless']
# Pred: ['She', 'is', 'weak', 'and', 'useless', ' ', 'ime ', 'un ', 'er ', 'ff']
#
# Text: ['Race is a social construction -- zero out skin color and some people will just find new and equally stupid reasons to hate.  See, for instance, sectarian violence in Northern Ireland, genocide in Rwanda, etc., for cases where idiots rose above common skin color to express their needs for bigotry.']
# Gold: ['stupid', 'idiots']
# Pred: ['Race', 'social', 'construction', 'zero', 'out', 'skin', 'color', 'find', 'new', 'equally', 'reasons', 'hate.', ' fo', 'e', ' sectaria', ' violenc', ' i', ' Norther', ' genocid', ' i', 'c', ' fo', ' idio', ' abov', ' commo', ' ski', ' colo', ' fo', 'try']
#
# Text: ['Had no idea there were so many stinkin, rotten, douchebag democrats in our great state....wow....']
# Gold: ['stinkin, rotten, douchebag democrats']
# Pred: ['Had', 'there', 'so', 'tin', ',', 'rotten,', 'do', 'bag', 'demo', 'in', 'great', 'state', '.']
#
# Text: ['crisis?  sure\n\nbut this is also about free choice....so the government has to step in to stop morons for taking chinese fentenyl?\n\nso people in BC are extra stupid?  sounds like it']
# Gold: ['morons']
# Pred: ['crisis?', '\n\nb', 't th', 'o abo', 't fr', 'e choic', 'e governme', ' mo', 's f', 'r taki', 'g ch', ' fenteny', '?\n', 'so peo', 'le', 'in', 're ex', 'p', 'nds ', 'ik']
#
# Text: ['Good ol Doug Chinn,  busy on the campaign trail.  somebody deport this kook!']
# Gold: ['kook']
# Pred: ['Good', 'ol', 'Doug', 'Chin', ',', ' o', 'depo']
#
# Text: ["Heck, I remember when you couldn't leave your horse tied up outside without some idiot stealing it."]
# Gold: ['idiot']
# Pred: ['He', ',', 'I', 'remember', 'you', "'", 'your', 'horse', 'idiot', 'stealing', 'it.']
#
# Text: ['der trumpf initiated this crap.....now he turns around as if he had nothing to do with it.....except criticize a program that helps people......time for this insane idiot to go!']
# Gold: ['crap', 'idiot']
# Pred: ['der', 'rump', 'ow ', 'ad ', 'othing ', 'o ', 'ritici', 'rogram ', 'eople..', 'ime ', 'o!']
#
# Text: ['I vote for #1 - he is ... observably insane.']
# Gold: ['insane']
# Pred: ['I', 'vote', '#', '-', 'er', 'insane', '']
#
# Text: ['Monsef is an idiot and should be turfed from the Cabinet ....but Comrade Sunny Days is too enamoured with her....']
# Gold: []
# Pred: ['Monsef', 'an', 'idiot', 'and', 'should', 'turf', 'from', 'the', 'Cabinet', '.', 'but', 'Co', 'rade', 'Sunny', 'with', 'her', '.', '']
#
# Text: ["It will be interesting to see how the right deals with (or doesn't) with O'Lielly. We've already seen that the LEFT is consistent in their values when it comes to Weinstein - they've condemned and cut ties to him, etc.\n\n\nHow much time do you think the right will spend on O'Lielly's predation? Even 1/10th the time they spent on Weinstein? Or will they, once again, be flaming hypocrites on this?"]
# Gold: ['flaming hypocrites']
# Pred: ['It', 'interesting', 'see', 'right', 'with', '(or', "'", "O'Lie", "We've", 'seen', 'that', 'L', 'T', 'consistent', 'in', 'values', 'Wei', '-', "'ve", 'condemned', 'ties', ',', 'etc', '\n\nH', 'h ti', 'e ', 'e rig', 'd ', "n O'L", 'l', 'n', '1/10', 'h t', 'e ti', 'y spe', 't ', 'n W', '? ', 'e flami', ' ', 'p', 's ', 'i']
#
# Text: ['blow harder. what a blow job']
# Gold: ['blow job']
# Pred: ['blow', 'harder', 'what', 'a', 'blow', 'job']
#
# Text: ['UR pathetic.']
# Gold: []
# Pred: ['UR', 'pathetic', '']
#
# Text: ['Sick.  Truly sick.  No doubt you have case citations for us?']
# Gold: ['Sick', 'Truly sick']
# Pred: ['Sick', ' ', 'ruly', ' ', 'have', 'case', 'citation', 'for', '?']
#
# Text: ['Sorry old man....I knew you were a DRUNK!\nDuring  the 5 years in Alaska we have grossed 1.5 million dollars\nwww.thehealingcentermedicalclinic.org']
# Gold: ['DRUNK']
# Pred: ['Sorry', '.', 'you', 'were', 'a', 'UNK', 'uring ', 'in', 'have', '5', '.', 'healing', 'ermedicalclini', '.']
#
# Text: ['It always amazes us, that the world \nhas idiots who helieve this drivel.']
# Gold: ['idiots']
# Pred: ['It', ',', 'world', ' idio', ' heli', ' driv', 'l']
#
# Text: ['You are spouting nonsense.']
# Gold: ['nonsense']
# Pred: ['You', 'are', 'po', '']
#
# Text: ["The truth hurts so you have to resort to idiotic comments you just don't understand how ignorant you are."]
# Gold: ['idiotic', 'ignorant']
# Pred: ['The', 'truth', 'so', 'have', 'resort', 'idiot', 'comments', 'you', 'just', "don'", 'understand', 'you', 'are.']
#
# Text: ["They have the White House, the House, and the Senate and they can't govern themselves out of a paper bag.  But hey, keep ginning up the race baiting cause that'll get the twice removed judge into office.  Maybe that idiot will help you."]
# Gold: ['idiot']
# Pred: ['They', 'have', 'White', 'House,', 'the', 'House,', 'the', 'and', "'", 'out', 'of', '.', ' Bu', ' he', ' u', ' rac', ' caus', 't', ' ge', ' twic', ' remove', ' int', ' office', '  May', 'o']
#
# Text: ['re: Everyone who owns a house has benefited from idiotic rises in housing prices.\n\nNo, only people who have sold (and not re-bought, or re-bought, but in a cheaper geographical market than they sold) have benefitted. People that think they benefitted, by taking out equity to reno or do other things with, but have not sold, or have sold and "upgraded" will not have benefitted as a portion of their "equity" will disappear over the next couple of years with rate increases and probably will not return for a very long time (decade or so). Everybody else who just live in their homes and didn\'t borrow anything against them as they skyrocketed in value, how have they benefitted?']
# Gold: ['idiotic']
# Pred: ['re:', 'Everyone', 'who', 'house', 'has', 'idiot', 'in', 'housing', '.', '\nNo', ' onl', ' peopl', ' wh', ' hav', ' sol', ' (an', ' re-bought', ' o', ' re-bought', ' bu', ' i', ' cheape', ' geographica', ' marke', ' tha', ' sol', ' hav', ' benefi', 'd', ' Peopl', ' tha', ' thin', ' benefitted', ' takin', ' ou', ' ren', ' o', ' d', ' othe', ' thing', ' with', ' bu', ' hav', ' sold', ' o', ' hav', ' sol', ' "upgrade', ' no', ' hav', ' benefi', ' a', ' "equit', ' o', ' an', ' probabl', ' no', ' retur', ' (decad', ' s', ')', ' Everybod', ' els', ' wh', ' liv', ' home', 'n', ' anythin', ' i', ' valu', ' hav']
#
# Text: ['I love how fellow troglodytes vote in agreement with you despite your falsehoods.   Let me see our middle class taxes were lowered and this also benefits the wealthy (but yes they did rise for those making over $200k - boo hoo).  Our corporate taxes are already in the 10-15% range and have been for a long time.   So where are these tax increased under Wynne or Trudeau, name them???   \n\nYou believe Trump can get rid of half (just a guess) of federal revenue and it will benefit society?  You think that is how it works?  Do tell.   How does the fact that within the next 20 years we will ALL lose another 10-20% of jobs due to technology?  Tell me how that factors in for you?  What about the fact that globally we are adding about 80 million more people a year but require less labour?  How does that factor in, let me tell you?  Should we always just let the .01% reap the benefits of technology none of them have invented?   Simple minded answers are for the far right among us.']
# Gold: ['troglodytes']
# Pred: ['I', 'love', 'roglodytes', 'despite', 'false', '  L', 't ', 'e o', 'r midd', 'e cla', 'd a', 'd th', 's al', 'o benefi', 'e wealt', 'y', 'e f', 'r tho', 'e maki', 'g ov', 'r $2', '-', 'o ', '.  ', 'ur corpor', 'dy', 'he', '10', '5% ra', 'nd h', 'e.', '  So ', 'n', ' th', 'm??', ' ', ' (jus', ' it wil', ' benefi', 'soc', 'ety? ', 'it', 's', '  D', 'How ', ' the ', 'ea', 'lo', 'a', 'ot', '-20', 'no', ' t', 'at ', 'o', 's in', 'for y', 'What', 'abou', 'at ', 'loball', ' we a', 'out ', ' pe', 'ar b', 'i', 'e l', '  How ', 'oe', 'et me ', 'a', 'ea', ' the benef', ' t', 'ogy ', 'min', ' for ', ' ']
#
# Text: ['I know its exactly the same with the morons who conflate footballers and football.']
# Gold: ['morons']
# Pred: ['I', 'its', 'same', 'with', 'oro', 'footballer', 'and', 'football.']
#
# Text: ['An idiot named Hillary happened']
# Gold: ['idiot']
# Pred: ['An', 'idiot', 'named', 'Hillary', 'happened']
#
# Text: ['Lets just coddle these idiotic standoff perps and let them have their way. Next thing you know bank robbers will be given getaway cars for their timely escape. We dont want these criminals to be late to the next hillary rally.']
# Gold: ['idiotic']
# Pred: ['Lets', 'co', 'per', '.', 'Next', 'thing', 'you', 'bank', 'getaway', 'cars', 'for', 'escape.', 'dont', 'want', 'ary', 'rally.']
#
# Text: ['What the Hells wrong with you dude...']
# Gold: []
# Pred: ['What', 'wrong', 'with', 'you', 'dude.', '.']
#
# Text: ["They ought to FIRE non attenders. Sends the message that they don't give a flying F * * K about the People of HNL!"]
# Gold: ['F * * K']
# Pred: ['They', 'ought', 'F', 'E', 'non', '.', 'message', 'that', "don't", 'K', 'People', 'of']
#
# Text: ['typical hate bases left wing stupidity, this was one great person']
# Gold: ['stupidity']
# Pred: ['typical', 'hate', 'bases', 'left', 'ity', ' ', 'his ', 'ne ', 'reat ', 'erson']
#
# Text: ["Trump is a buffoon.\nAnd a traitor.\nHe has absolutely no redeeming qualities whatsoever.\nHe's disgusting."]
# Gold: ['Trump', 'buffoon', 'disgusting']
# Pred: ['Trump', 'oon', '\n', 'nd ', 'raitor.\n', 'as ', 'o ', 'eming ', 'ualities ', 'hatsoever.\n', 's', 'isgusting.', '']
#
# Text: ['You are both pig ignorant and a liar.']
# Gold: []
# Pred: ['You', 'are', 'both', 'pig', 'ignorant', 'a', '.']
#
# Text: ['you are a delusional lib troll of stupid, canada  is not doing squat in the world other than paying for access with justin... here we laugh at his bs and lack of any sense of what an economy is, thats not hate loser, thats reality']
# Gold: ['stupid']
# Pred: ['you', 'a', 'del', 'ib', 'of', 'stupid', ' ', 'not', 'doing', 'in', 'world', 'paying', 'for', 'access', '...', 'here', 'b', 'of', 'any', 'of', 'economy', ',', 'that', 'hate', ',', 'reality']
#
# Text: ['Save it. Damn the developers.']
# Gold: ['Damn']
# Pred: ['Save', 'it', 'Damn', 'developers']
#
# Text: ['oh! wait! you already burned down to a crisp in fort mac by your own stupidity, already. Stay the hell away from BC, you f*cking idiots.']
# Gold: ['stupidity', 'f*cking', 'idiots']
# Pred: ['oh', '!', 'you', 'burned', 'in', 'fort', 'mac', 'by', 'your', 'ity', ' ', ' ', 'tay ', 'way ', 'C, ', '*cking ', '']
#
# Text: ['This clearly is why "Junior" is not qualified to be PM........he\'s an idiot !']
# Gold: ['idiot']
# Pred: ['This', 'clearly', 'is', 'why', '"Junior', 'not', 'qualified', 'to', 'be', 'PM', "'", 'an', 'idiot', '!']
#
# Text: ["We aren't California or New York .    You obviously don't pay the ever rising taxes, but I do and the personal  incomes in this town  don't support them and I'm sick of them being raised on a yearly basis to support the freeloaders and things like stupid and unneeded roundabouts so the current mayor can have some sort of legacy after he's booted out of office."]
# Gold: ['stupid']
# Pred: ['We', "aren't", 'California', 'or', 'New', 'York', '.', '   ', 'ou obviou', 'ly do', "'t ", 'he e', 'er ris', 'x', 's, ', 'u', ' I', 'do ', 'nd ', 'he perso', 'al  in', 'me', 'his ', ' ', 'the', ' an', 'si', 'por', ' the freelo', 'der', ' and t', 'ings', 'nd ', 'rounda', 'ou', 'e', ' o', 't of of']
#
# Text: ['No it doesn’t.  Talking about superstition RP, you still believe in Hillary Clinton.  Sorry, I didn’t mean to mock your false god.']
# Gold: ['RP', 'I didn’t mean to mock your false god']
# Pred: ['No', 'doesn’', '.', ' Talkin', ' supers', ' R', ',', '.', 'n', ' fals', ' go', '.']
#
# Text: ["Lol they all steal. We supported eu too. You think democrats don't enjoy it. Now explain why both sides disliked trump? Probably because he heartened to bring down there game. Thanks for pointing out that trump wasn't a thing during brexit. Once again couldn't figure out the point. People dislike the guise of refugees/ immigrants and the lovey dovey BS that goes along with it. I don't need a lesson on that and it was not even my point. Once again trump and farage and the next eu leaders are very relative to the point of immigration. My second point was the fact that all countries steal from there citizens and launder. We citizens get screwed from every country. You can say the we launder to the USA but it's politicians, republican and democrat. The USA launders to ME, Canada etc and the liberals and conservatives here are happy. They all seem to dislike trump which should be a big clue to his relativity in not only immigration but all policies. Once again I can clearly see the idiot."]
# Gold: ['steal', 'idiot']
# Pred: ['Lo', 'steal', ' ', 'e ', 'oo. ', 'ou ', 'emoc', 't', 'oth ', ' ', ' ', 't', 'hing ', ' ', 'nce ', 't', 'igure ', 'oint. ', 'f ', 'efugees/ ', 'mmigrants ', 'ovey', "on't ", 'eed ', ' ', 'esson ', 'n ', 'nd ', 't ', 'oint. ', 'ump ', 'ara', 'nd ', 'he ', 'ext ', ' ', 'elative ', 'f ', 'y ', 'oint ', 'act ', 'teal ', 'here ', 'itizens ', ' ', 'itizens ', 'crewed ', 'rom ', 'ountry. ', 'ou ', 'r ', 'o ', 'he ', 'SA ', 'ut ', 's', 'epublican ', 'emoc', ' ', 'he ', 'o ', 'E, ', 'tc ', 'nd ', 'iberals', 'onservatives', ' ', 'hich ', 'ig ', 'lue ', 'elativity ', 'n ', 'learly ', 'diot.', '']
#
# Text: ['Shut the fuck up. This man was my father. You have no clue what the cause of this nor the situation. "Truckers should really slow down in these areas" go fuck yourself. A man died and that\'s what you have to say. Go fuck yourself']
# Gold: ['go fuck yourself', 'fuck']
# Pred: ['Shut', 'fuck', '.', 'my', 'father.', 'You', 'have', 'no', 'clue', 'what', 'cause', 'of', 'this', 'nor', 'situation.', '"Truckers', 'should', 'in', 'these', 'areas"', 'yourself', ' ', ' ', 'an ', 'nd ', 's', 'ave ', 'ay. ', 'ourself']
#
# Text: ['Another idiot!']
# Gold: ['idiot']
# Pred: ['Another', 'idiot', '']
#
# Text: ["What in the heck are you talking about?  This has absolutely nothing to do with the government or Obama.  This is entirely a result of TSA's inability to adjust to modern spending habits.  Look how many Amazon boxes show up in your neighborhood everyday.  Your prejudice is unmistakeable and completely idiotic."]
# Gold: ['idiotic']
# Pred: ['What', 'are', 'you', 'about?', ' Thi', ' ha', ' nothin', ' t', ' d', ' governmen', '  Th', 's entire', 'a resu', 't ', 'f TS', 's inabili', 'ny Ama', 'd', 'y.  ', 'our preju', 'take', 'and comple', 'ely idi', 't']
#
# Text: ['Amen Brother Richard ... what the heck is WRRROOOOONNNNGGG as Cheetolini would say with these whacked out hillbilly Republicans that voted for this MONSTER ...']
# Gold: ['hillbilly Republicans']
# Pred: ['Am', 'Brother', 'Richard', '..', 'what', 'heck', 'WRR', 'Cheetolini', 'hill', 'y', 'that', 'for', 'this', 'M', 'ER', '...']
#
# Text: ['Adding more environmental disasters ADDS MORE TOXINS YOU STUPID, STUPID, STUPID PEOPLE.\n\nIT WILL NOT BE BUILT YOU CORRUPT IDIOTS.']
# Gold: ['STUPID']
# Pred: ['Adding', 'more', 'environmental', 'AD', 'E', 'TOX', 'YOU', 'UPID', ' ', 'PID, ', 'TUPI', 'O', 'E.\n', 'IT', 'NO', 'YOU', 'CO', 'T', 'IDIO', '.']
#
# Text: ['Lame and stupid attempt at humor.']
# Gold: []
# Pred: ['Lam', 'attempt']
#
# Text: ["Butts butted in and spanked Justin's butt."]
# Gold: ['spanked', 'butt']
# Pred: ['But', 'in', "Justin'", 'butt', '']
#
# Text: ['Jenkins wishes he could be as big a buffoon as Trump.\nHis best efforts were 30 years ago.\nHe only achieved small mindedness, speciousness and sanctimony.\nSad. Weak.']
# Gold: ['buffoon', 'Sad', 'Weak']
# Pred: ['Jenkins', 'wishes', 'be', 'as', 'oon', 'as', '.', 'His', 'best', 'efforts', 'were', 'years', 'ago', 'achieved', 'ness', 'pec', 'ness', 'ti', '']
#
# Text: ['During confirmation hearings, over a dozen of Trump cabinet appointees have testified under oath that Trump is wrong and ignorant.']
# Gold: ['ignorant']
# Pred: ['During', 'of', 'Trump', 'cabinet', 'appointees', 'have', 'that', 'Trump', 'wrong', '']
#
# Text: ["This is what happens when people start to become so dependent on government that they won't even discipline their own kids. This is very similar to the 1950's and '60's fear of excessive television watching by children.  Thank goodness the neighborhood police spy network didn't have the cops kick in living room doors and arrest parents for allowing their children to watch BONANZA. If you will pay through the nose to let your preteen live online, your kid will probably grow up dumber than you... but not by much."]
# Gold: ['dumber']
# Pred: ['This', 'what', 'happens', 'so', 'government', "'", 'own', 'kids.', 'This', 'very', 'similar', 'to', "'", "'", 'of', 'excessive', '.', ' Than', ' goodnes', ' neighborhoo', ' sp', ' networ', 'n', ' kic', ' i', ' livin', ' fo', 'ZA', ' I', ' yo', ' nos', ' ki', ' probabl', ' gro', ' u', 'be', 'u', '.', ' bu', ' much']
#
# Text: ["A hell of a lot more than republicans have to show.  Hell the idiots couldn't even replace Obama care, something they have run against for the past 7 years.  When the economy crashes, it will be interesting to see just what the hell republicans will do?  Anything?"]
# Gold: ['idiots']
# Pred: ['A', 'of', 'lot', 'more', 'than', ' Hel', ' idio', 'n', ' replac', ' car', ' somethin', ' hav', ' ru', ' ', ' year', 'l ', '?  Anyth']
#
# Text: ['http://www.politicususa.com/2016/09/02/trump-craven-maniacal-david-bossie-clinton-character-assassin.html\n\nNew Trump Hire Proves Hillary Clinton’s Vast Right Wing Conspiracy is Real\nTrump\'s new Deputy Campaign Manager, Citizens United President David Bossie, "has devoted his career ever since to trying to tear down Hillary Clinton"\n\nThere is no disguising the truth: Bossie will be assisting Kellyanne Conway as an anti-Clinton character assassin, and Hillary for America Chair John Podesta released the following statement:\n\n“David Bossie is so craven and maniacal that in the heyday of the overreaching, Gingrich-era Congress, the top Whitewater conspiracy theorist in the House had to fire him for doctoring evidence. He has devoted his career ever since to trying to tear down Hillary Clinton\n\nAnother liar just like Trump. I think only idiots..............']
# Gold: ['idiots']
# Pred: ['http://www', 'oli', 'com/', '/', '/', 'rump-', 'rave', '-', 'al-david-', '-', 'linton-character-assassin.html', '\nNe', 'ir', ' Pr', 'n', ' Righ', ' Co', 'pirac', ' i', ' Rea', ' ne', ' Deput', 'r', ' Citizen', ' Unite', ' Presiden', ' Davi', 'sie', '"ha', ' devote', ' eve', ' tryin', 'n', '\n\nThe', 's ', 'guisi', 't', 'ss', 'e wi', 'l ', 'g Kellyan', 'e Conw', 'y ', 's ', 'n ant', 'n charact', 'r assassi', ', a', 'y f', 'r Ameri', 'r Jo', 'n ', 'es', 'd t', 'e followi', 'g statemen', ':\n\n“Da', 'ie', 'is', 'o cr', 'ia', 'al t', 'ay', 'he over', 'i', 'g', 'ra Congr', 'he ', 'op Whitewa', 'cy theor', 'st', 'he Ho', 'to f', 'im ', 'or doc', 'n', 'as devo', 'er e', 'to try', 'on\n\nAno', '. I t', '.']
#
# Text: ['Same old crap yell racism when he is losing the argument. Typical liberal.']
# Gold: ['Typical liberal']
# Pred: ['Same', 'yell', 'racism', 'is', 'argument', 'liberal', '']
#
# Text: ["had this happened, had that happened.... so what - how stupid.  He'll never catch Gretzky"]
# Gold: ['stupid']
# Pred: ['had', 'happened,', 'had', 'that', 'happened', 'so', 'what', 'how', ' ', "'", 'ret']
